# %% [markdown]
# Import the BCC data into a pandas dataframe

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
bccdf = pd.read_csv('breast-cancer-wisconsin.data')
bccdf
# Out:
#      SampleCode  Clump Thickness  Uniformity of Cell Size  \
# 0       1000025                5                        1
# 1       1002945                5                        4
# 2       1015425                3                        1
# 3       1016277                6                        8
# 4       1017023                4                        1
# ..          ...              ...                      ...
# 694      776715                3                        1
# 695      841769                2                        1
# 696      888820                5                       10
# 697      897471                4                        8
# 698      897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# ..                        ...                ...                          ...
# 694                         1                  1                            3
# 695                         1                  1                            2
# 696                        10                  3                            7
# 697                         6                  4                            3
# 698                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0             1                3                1        1      2
# 1            10                3                2        1      2
# 2             2                3                1        1      2
# 3             4                3                7        1      2
# 4             1                3                1        1      2
# ..          ...              ...              ...      ...    ...
# 694           2                1                1        1      2
# 695           1                1                1        1      2
# 696           3                8               10        2      4
# 697           4               10                6        1      4
# 698           5               10                4        1      4
#
# [699 rows x 11 columns]

# %%
bccdf.dtypes
# Out:
# SampleCode                      int64
# Clump Thickness                 int64
# Uniformity of Cell Size         int64
# Uniformity of Cell Shape        int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Bland Chromatin                 int64
# Normal Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
bccdf['Bare Nuclei'].unique()
# Out:
# array(['1', '10', '2', '4', '3', '9', '7', '?', '5', '8', '6'],
#       dtype=object)

# %%
bccdf = bccdf[bccdf['Bare Nuclei'] != '?'] #bccdf where its category bare nuclei doesnt equal an unknown
bccdf
# Out:
#      SampleCode  Clump Thickness  Uniformity of Cell Size  \
# 0       1000025                5                        1
# 1       1002945                5                        4
# 2       1015425                3                        1
# 3       1016277                6                        8
# 4       1017023                4                        1
# ..          ...              ...                      ...
# 694      776715                3                        1
# 695      841769                2                        1
# 696      888820                5                       10
# 697      897471                4                        8
# 698      897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# ..                        ...                ...                          ...
# 694                         1                  1                            3
# 695                         1                  1                            2
# 696                        10                  3                            7
# 697                         6                  4                            3
# 698                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0             1                3                1        1      2
# 1            10                3                2        1      2
# 2             2                3                1        1      2
# 3             4                3                7        1      2
# 4             1                3                1        1      2
# ..          ...              ...              ...      ...    ...
# 694           2                1                1        1      2
# 695           1                1                1        1      2
# 696           3                8               10        2      4
# 697           4               10                6        1      4
# 698           5               10                4        1      4
#
# [683 rows x 11 columns]

# %%
bccdf.dropna() ##Remove missing values.
# Out:
#      SampleCode  Clump Thickness  Uniformity of Cell Size  \
# 0       1000025                5                        1
# 1       1002945                5                        4
# 2       1015425                3                        1
# 3       1016277                6                        8
# 4       1017023                4                        1
# ..          ...              ...                      ...
# 694      776715                3                        1
# 695      841769                2                        1
# 696      888820                5                       10
# 697      897471                4                        8
# 698      897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# ..                        ...                ...                          ...
# 694                         1                  1                            3
# 695                         1                  1                            2
# 696                        10                  3                            7
# 697                         6                  4                            3
# 698                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0             1                3                1        1      2
# 1            10                3                2        1      2
# 2             2                3                1        1      2
# 3             4                3                7        1      2
# 4             1                3                1        1      2
# ..          ...              ...              ...      ...    ...
# 694           2                1                1        1      2
# 695           1                1                1        1      2
# 696           3                8               10        2      4
# 697           4               10                6        1      4
# 698           5               10                4        1      4
#
# [683 rows x 11 columns]

# %%
bccdf = bccdf.drop(columns = ['SampleCode'])
bccdf.Class = (bccdf.Class - 2)/2
sns.pairplot(bccdf)

# %%
corr = bccdf.corr()
sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=True, cmap= 'RdBu')
# Out:
# <AxesSubplot: >

# %%
X_train, X_test, y_train, y_test = train_test_split(bccdf.drop(['Class'], axis=1), bccdf.Class, test_size=0.2, random_state=21)

# %%
X_train
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 115                1                        1                         1
# 59                 9                        5                         5
# 111                8                        6                         4
# 609                5                        1                         1
# 446                1                        1                         1
# ..               ...                      ...                       ...
# 434                6                        9                         7
# 122               10                       10                        10
# 382                3                        2                         2
# 50                 9                        5                         8
# 213               10                       10                        10
#
#      Marginal Adhesion  Single Epithelial Cell Size Bare Nuclei  \
# 115                  1                            2           5
# 59                   2                            2           2
# 111                  3                            5           9
# 609                  1                            2           1
# 446                  1                            2           1
# ..                 ...                          ...         ...
# 434                  5                            5           8
# 122                  2                           10          10
# 382                  2                            2           1
# 50                   1                            2           3
# 213                 10                            7          10
#
#      Bland Chromatin  Normal Nucleoli  Mitoses
# 115                1                1        1
# 59                 5                1        1
# 111                3                1        1
# 609                1                1        1
# 446                1                1        1
# ..               ...              ...      ...
# 434                4                2        1
# 122                5                3        3
# 382                3                2        1
# 50                 2                1        5
# 213                7               10        4
#
# [546 rows x 9 columns]

# %%
y_train
# Out:
# 115    0.0
# 59     1.0
# 111    1.0
# 609    0.0
# 446    0.0
#       ...
# 434    0.0
# 122    1.0
# 382    0.0
# 50     1.0
# 213    1.0
# Name: Class, Length: 546, dtype: float64

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.03052106, 0.02897114, 0.01509576, 0.01302417, 0.00788995,
#        0.04337238, 0.01392089, 0.01546489, 0.00422993])

# %%
yhat_train = reg.predict(X_train)
yhat_test = reg.predict(X_test)

# %%
print('\nMean squared error: %.2f' % mean_squared_error(y_train, yhat_train))
print('\nMean squared error: %.2f' % mean_squared_error(y_test, yhat_test))
# Out:
# Mean squared error: 0.04
#
# Mean squared error: 0.04

# %%
from sklearn.metrics import classification_report

# %%
yhat_test[0:20]
# Out:
# array([ 0.80896461,  0.72549656, -0.06433751,  0.12207456,  0.02722568,
#        -0.0417064 ,  1.11774731,  0.92077138,  0.17385386,  0.8428757 ,
#         0.07284251,  0.96521767,  0.12741097, -0.04438569,  0.0106255 ,
#        -0.05830658,  0.00704949,  0.84968703,  0.00671995, -0.05041663])

# %%
yhat_test2 = [ 1 if y>=0.5 else 0 for y in yhat_test ]
yhat_test2[0:20]
# Out:
# [1, 1, 0, 0, 0, 0, 1, 1, 0, 1, 0, 1, 0, 0, 0, 0, 0, 1, 0, 0]

# %%
print(classification_report(y_test, yhat_test2))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        84
#          1.0       1.00      0.92      0.96        53
#
#     accuracy                           0.97       137
#    macro avg       0.98      0.96      0.97       137
# weighted avg       0.97      0.97      0.97       137

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
yhat_test = logreg.predict(X_test)

# %%
logreg.score(X_test, y_test)
# Out:
# 0.9708029197080292

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, yhat_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.98        84
#          1.0       1.00      0.92      0.96        53
#
#     accuracy                           0.97       137
#    macro avg       0.98      0.96      0.97       137
# weighted avg       0.97      0.97      0.97       137

# %%
logreg.coef_[0]
# Out:
# array([0.51189123, 0.07806344, 0.31837642, 0.33277616, 0.11420275,
#        0.32199638, 0.4069301 , 0.16553989, 0.481485  ])

# %%
sns.scatterplot(x = list(range(0,len(logreg.coef_[0]))),y = logreg.coef_[0])
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Neural Nets

# %% [markdown]
# Now I'm going to use Keras to define a Neural network that will be trained off of this data. This Neural Network can then be used to predict future values for breast cancer presence.

# %%
from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential() # Initialising the ANN

classifier.add(Dense(units = 16, activation = 'relu', input_dim = 9))
classifier.add(Dense(units = 8, activation = 'relu'))
classifier.add(Dense(units = 6, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %% [markdown]
# Once the Neural Network is defined, I now have to specify is the optimizer and loss function

# %%
classifier.compile(optimizer = 'rmsprop', loss = 'binary_crossentropy')

# %%
X_train.astype(float)
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 115              1.0                      1.0                       1.0
# 59               9.0                      5.0                       5.0
# 111              8.0                      6.0                       4.0
# 609              5.0                      1.0                       1.0
# 446              1.0                      1.0                       1.0
# ..               ...                      ...                       ...
# 434              6.0                      9.0                       7.0
# 122             10.0                     10.0                      10.0
# 382              3.0                      2.0                       2.0
# 50               9.0                      5.0                       8.0
# 213             10.0                     10.0                      10.0
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 115                1.0                          2.0          5.0
# 59                 2.0                          2.0          2.0
# 111                3.0                          5.0          9.0
# 609                1.0                          2.0          1.0
# 446                1.0                          2.0          1.0
# ..                 ...                          ...          ...
# 434                5.0                          5.0          8.0
# 122                2.0                         10.0         10.0
# 382                2.0                          2.0          1.0
# 50                 1.0                          2.0          3.0
# 213               10.0                          7.0         10.0
#
#      Bland Chromatin  Normal Nucleoli  Mitoses
# 115              1.0              1.0      1.0
# 59               5.0              1.0      1.0
# 111              3.0              1.0      1.0
# 609              1.0              1.0      1.0
# 446              1.0              1.0      1.0
# ..               ...              ...      ...
# 434              4.0              2.0      1.0
# 122              5.0              3.0      3.0
# 382              3.0              2.0      1.0
# 50               2.0              1.0      5.0
# 213              7.0             10.0      4.0
#
# [546 rows x 9 columns]

# %% [markdown]
# You now train the neural network using Classifier.fit, passing it the training data -- i.e. for this set of X, this is what the Y should look like. The NN will then spot the patterns in the data, and build a neural network that could replicate that.

# %%
classifier.fit(X_train.astype(float), y_train, batch_size = 1, epochs = 100)
# Out:
# Epoch 1/100
# 546/546 [==============================] - 1s 897us/step - loss: 0.8851
# Epoch 2/100
# 546/546 [==============================] - 1s 1ms/step - loss: 0.4551
# Epoch 3/100
# 546/546 [==============================] - 0s 899us/step - loss: 0.3604
# Epoch 4/100
# 546/546 [==============================] - 0s 893us/step - loss: 0.2986
# Epoch 5/100
# 546/546 [==============================] - 0s 899us/step - loss: 0.2669
# Epoch 6/100
# 546/546 [==============================] - 1s 954us/step - loss: 0.2402
# Epoch 7/100
# 546/546 [==============================] - 0s 895us/step - loss: 0.2263
# Epoch 8/100
# 546/546 [==============================] - 0s 883us/step - loss: 0.2209
# Epoch 9/100
# 546/546 [==============================] - 0s 862us/step - loss: 0.1973
# Epoch 10/100
# 546/546 [==============================] - 1s 900us/step - loss: 0.1795
# Epoch 11/100
# 546/546 [==============================] - 1s 905us/step - loss: 0.2127
# Epoch 12/100
# 546/546 [==============================] - 0s 868us/step - loss: 0.1787
# Epoch 13/100
# 546/546 [==============================] - 0s 864us/step - loss: 0.1641
# Epoch 14/100
# 546/546 [==============================] - 1s 907us/step - loss: 0.1798
# Epoch 15/100
# 546/546 [==============================] - 0s 903us/step - loss: 0.1742
# Epoch 16/100
# 546/546 [==============================] - 0s 882us/step - loss: 0.1669
# Epoch 17/100
# 546/546 [==============================] - 0s 875us/step - loss: 0.1786
# Epoch 18/100
# 546/546 [==============================] - 1s 985us/step - loss: 0.1552
# Epoch 19/100
# 546/546 [==============================] - 1s 942us/step - loss: 0.1634
# Epoch 20/100
# 546/546 [==============================] - 0s 883us/step - loss: 0.1685
# Epoch 21/100
# 546/546 [==============================] - 0s 875us/step - loss: 0.1426
# Epoch 22/100
# 546/546 [==============================] - 0s 909us/step - loss: 0.1609
# Epoch 23/100
# 546/546 [==============================] - 0s 907us/step - loss: 0.1529
# Epoch 24/100
# 546/546 [==============================] - 0s 909us/step - loss: 0.1548
# Epoch 25/100
# 546/546 [==============================] - 0s 860us/step - loss: 0.1572
# Epoch 26/100
# 546/546 [==============================] - 1s 961us/step - loss: 0.1510
# Epoch 27/100
# 546/546 [==============================] - 1s 1ms/step - loss: 0.1432
# Epoch 28/100
# 546/546 [==============================] - 0s 900us/step - loss: 0.1356
# Epoch 29/100
# 546/546 [==============================] - 0s 907us/step - loss: 0.1546
# Epoch 30/100
# 546/546 [==============================] - 0s 915us/step - loss: 0.1367
# Epoch 31/100
# 546/546 [==============================] - 1s 958us/step - loss: 0.1401
# Epoch 32/100
# 546/546 [==============================] - 0s 851us/step - loss: 0.1288
# Epoch 33/100
# 546/546 [==============================] - 0s 881us/step - loss: 0.1574
# Epoch 34/100
# 546/546 [==============================] - 1s 1ms/step - loss: 0.1462
# Epoch 35/100
# 546/546 [==============================] - 1s 959us/step - loss: 0.1327
# Epoch 36/100
# 546/546 [==============================] - 1s 903us/step - loss: 0.1376
# Epoch 37/100
# 546/546 [==============================] - 0s 888us/step - loss: 0.1273
# Epoch 38/100
# 546/546 [==============================] - 1s 926us/step - loss: 0.1301
# Epoch 39/100
# 546/546 [==============================] - 0s 878us/step - loss: 0.1128
# Epoch 40/100
# 546/546 [==============================] - 1s 921us/step - loss: 0.1357
# Epoch 41/100
# 546/546 [==============================] - 0s 880us/step - loss: 0.1260
# Epoch 42/100
# 546/546 [==============================] - 1s 918us/step - loss: 0.1371
# Epoch 43/100
# 546/546 [==============================] - 0s 903us/step - loss: 0.1227
# Epoch 44/100
# 546/546 [==============================] - 0s 895us/step - loss: 0.1218
# Epoch 45/100
# 546/546 [==============================] - 0s 881us/step - loss: 0.1241
# Epoch 46/100
# 546/546 [==============================] - 1s 1ms/step - loss: 0.1022
# Epoch 47/100
# 546/546 [==============================] - 1s 948us/step - loss: 0.1178
# Epoch 48/100
# 546/546 [==============================] - 0s 868us/step - loss: 0.1015
# Epoch 49/100
# 546/546 [==============================] - 0s 904us/step - loss: 0.0943
# Epoch 50/100
# 546/546 [==============================] - 0s 911us/step - loss: 0.1207
# Epoch 51/100
# 546/546 [==============================] - 0s 868us/step - loss: 0.1060
# Epoch 52/100
# 546/546 [==============================] - 0s 863us/step - loss: 0.0972
# Epoch 53/100
# 546/546 [==============================] - 0s 884us/step - loss: 0.1159
# Epoch 54/100
# 546/546 [==============================] - 1s 920us/step - loss: 0.0838
# Epoch 55/100
# 546/546 [==============================] - 0s 907us/step - loss: 0.1116
# Epoch 56/100
# 546/546 [==============================] - 0s 881us/step - loss: 0.1147
# Epoch 57/100
# 546/546 [==============================] - 0s 856us/step - loss: 0.1157
# Epoch 58/100
# 546/546 [==============================] - 1s 935us/step - loss: 0.1320
# Epoch 59/100
# 546/546 [==============================] - 1s 1ms/step - loss: 0.1314
# Epoch 60/100
# 546/546 [==============================] - 0s 907us/step - loss: 0.1149
# Epoch 61/100
# 546/546 [==============================] - 1s 924us/step - loss: 0.1112
# Epoch 62/100
# 546/546 [==============================] - 1s 939us/step - loss: 0.1054
# Epoch 63/100
# 546/546 [==============================] - 1s 1ms/step - loss: 0.0878
# Epoch 64/100
# 546/546 [==============================] - 1s 937us/step - loss: 0.1076
# Epoch 65/100
# 546/546 [==============================] - 1s 924us/step - loss: 0.1367
# Epoch 66/100
# 546/546 [==============================] - 1s 946us/step - loss: 0.1198
# Epoch 67/100
# 546/546 [==============================] - 0s 867us/step - loss: 0.1264
# Epoch 68/100
# 546/546 [==============================] - 0s 871us/step - loss: 0.1088
# Epoch 69/100
# 546/546 [==============================] - 0s 897us/step - loss: 0.1016
# Epoch 70/100
# 546/546 [==============================] - 0s 912us/step - loss: 0.0978
# Epoch 71/100
# 546/546 [==============================] - 1s 925us/step - loss: 0.1360
# Epoch 72/100
# 546/546 [==============================] - 0s 881us/step - loss: 0.1336
# Epoch 73/100
# 546/546 [==============================] - 0s 914us/step - loss: 0.1137
# Epoch 74/100
# 546/546 [==============================] - 1s 916us/step - loss: 0.1148
# Epoch 75/100
# 546/546 [==============================] - 0s 886us/step - loss: 0.1004
# Epoch 76/100
# 546/546 [==============================] - 0s 863us/step - loss: 0.1307
# Epoch 77/100
# 546/546 [==============================] - 1s 921us/step - loss: 0.1024
# Epoch 78/100
# 546/546 [==============================] - 1s 937us/step - loss: 0.1170
# Epoch 79/100
# 546/546 [==============================] - 0s 899us/step - loss: 0.1292
# Epoch 80/100
# 546/546 [==============================] - 0s 869us/step - loss: 0.0848
# Epoch 81/100
# 546/546 [==============================] - 1s 1ms/step - loss: 0.1046
# Epoch 82/100
# 546/546 [==============================] - 1s 928us/step - loss: 0.0997
# Epoch 83/100
# 546/546 [==============================] - 0s 883us/step - loss: 0.0981
# Epoch 84/100
# 546/546 [==============================] - 0s 873us/step - loss: 0.1030
# Epoch 85/100
# 546/546 [==============================] - 0s 897us/step - loss: 0.1014
# Epoch 86/100
# 546/546 [==============================] - 1s 933us/step - loss: 0.1248
# Epoch 87/100
# 546/546 [==============================] - 0s 895us/step - loss: 0.1168
# Epoch 88/100
# 546/546 [==============================] - 0s 864us/step - loss: 0.1003
# Epoch 89/100
# 546/546 [==============================] - 0s 889us/step - loss: 0.1019
# Epoch 90/100
# 546/546 [==============================] - 1s 911us/step - loss: 0.0960
# Epoch 91/100
# 546/546 [==============================] - 0s 894us/step - loss: 0.1005
# Epoch 92/100
# 546/546 [==============================] - 0s 892us/step - loss: 0.1064
# Epoch 93/100
# 546/546 [==============================] - 1s 918us/step - loss: 0.0898
# Epoch 94/100
# 546/546 [==============================] - 1s 940us/step - loss: 0.0924
# Epoch 95/100
# 546/546 [==============================] - 0s 881us/step - loss: 0.0862
# Epoch 96/100
# 546/546 [==============================] - 0s 888us/step - loss: 0.0961
# Epoch 97/100
# 546/546 [==============================] - 0s 902us/step - loss: 0.1270
# Epoch 98/100
# 546/546 [==============================] - 1s 930us/step - loss: 0.0879
# Epoch 99/100
# 546/546 [==============================] - 1s 936us/step - loss: 0.1015
# Epoch 100/100
# 546/546 [==============================] - 1s 979us/step - loss: 0.0944

# %% [markdown]
# To predict new values, the Neural Network uses classifier.predict. I'm going to pass it the test values for X (which the Neural Network hasn't previously seen) and it will give me back a set of predictions. These predicitons will be probabilities, so I will clean them up by saying that if thye are greater than .5, I'll make them 1, else I'll make them 0.

# %%
yhat_test = classifier.predict(X_test.astype(float))
print("yhat /n", yhat_test)
yy_test = y_test.astype(int).reset_index(drop = True)
print("yy_test /n", yy_test)
# Out:
# 5/5 [==============================] - 0s 1ms/step
# yhat /n [[9.99960184e-01]
#  [9.75233257e-01]
#  [6.96452815e-08]
#  [1.99571042e-03]
#  [1.16871217e-06]
#  [9.37458537e-08]
#  [9.99886215e-01]
#  [9.99983072e-01]
#  [2.93598958e-07]
#  [9.99977410e-01]
#  [2.34985191e-06]
#  [9.99971628e-01]
#  [1.59242583e-04]
#  [5.69872043e-07]
#  [7.27324107e-07]
#  [2.68058841e-07]
#  [9.41467590e-07]
#  [9.98888969e-01]
#  [8.51565716e-08]
#  [6.26027656e-07]
#  [1.53406563e-06]
#  [1.00000000e+00]
#  [1.00000000e+00]
#  [2.20312222e-06]
#  [9.99953270e-01]
#  [9.99863446e-01]
#  [1.08079398e-07]
#  [9.99928057e-01]
#  [1.00000000e+00]
#  [7.47553941e-07]
#  [9.99998093e-01]
#  [9.54363465e-01]
#  [8.93133521e-01]
#  [9.99985874e-01]
#  [1.13050794e-06]
#  [8.83407235e-01]
#  [2.18791297e-06]
#  [9.20285529e-05]
#  [4.45483311e-05]
#  [5.74938994e-08]
#  [9.99981105e-01]
#  [9.99974966e-01]
#  [2.68793337e-05]
#  [4.98456416e-07]
#  [2.21589071e-05]
#  [1.13050794e-06]
#  [4.23223853e-01]
#  [9.99867260e-01]
#  [8.83541020e-07]
#  [1.35368680e-07]
#  [1.16871217e-06]
#  [9.93487835e-01]
#  [6.26027656e-07]
#  [1.31857769e-06]
#  [9.99779761e-01]
#  [9.90157425e-01]
#  [6.26027656e-07]
#  [1.08079398e-07]
#  [7.60881051e-07]
#  [9.99728024e-01]
#  [9.99360025e-01]
#  [9.99994397e-01]
#  [7.86525369e-01]
#  [2.18791297e-06]
#  [1.00000000e+00]
#  [1.53406563e-06]
#  [3.07866052e-04]
#  [8.83541020e-07]
#  [1.92678229e-07]
#  [2.68058841e-07]
#  [9.99955535e-01]
#  [8.83541020e-07]
#  [4.70071435e-01]
#  [1.16871217e-06]
#  [9.99465942e-01]
#  [6.26027656e-07]
#  [1.00000000e+00]
#  [6.26027656e-07]
#  [9.99466419e-01]
#  [6.26027656e-07]
#  [2.20927352e-04]
#  [6.73939439e-07]
#  [1.18744288e-06]
#  [9.68372166e-01]
#  [1.99876231e-05]
#  [1.00000000e+00]
#  [3.23456188e-05]
#  [2.61819821e-07]
#  [1.20900280e-03]
#  [1.00000000e+00]
#  [4.94696280e-07]
#  [1.13050794e-06]
#  [9.99997616e-01]
#  [4.63708062e-07]
#  [8.28342381e-05]
#  [4.63708062e-07]
#  [1.00000000e+00]
#  [5.69872043e-07]
#  [7.27324107e-07]
#  [9.99398947e-01]
#  [7.27324107e-07]
#  [1.24519988e-06]
#  [3.08692449e-07]
#  [1.00000000e+00]
#  [1.41530000e-02]
#  [9.96831715e-01]
#  [3.24503276e-06]
#  [1.13170966e-08]
#  [9.99573588e-01]
#  [1.03185926e-06]
#  [9.99964893e-01]
#  [7.27324107e-07]
#  [4.98456416e-07]
#  [4.83833246e-05]
#  [1.09561341e-07]
#  [9.98164773e-01]
#  [1.08079398e-07]
#  [9.43572729e-07]
#  [1.03353784e-07]
#  [1.09989696e-06]
#  [8.68715433e-05]
#  [9.99925017e-01]
#  [8.91290028e-08]
#  [1.13050794e-06]
#  [2.68058841e-07]
#  [6.96452815e-08]
#  [1.00000000e+00]
#  [9.99999821e-01]
#  [1.00000000e+00]
#  [1.16871217e-06]
#  [7.47553941e-07]
#  [9.98927414e-01]
#  [2.38034409e-06]
#  [2.24110408e-07]
#  [5.34420508e-07]
#  [9.98397887e-01]
#  [8.20253134e-01]]
# yy_test /n 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 132    0
# 133    0
# 134    0
# 135    1
# 136    0
# Name: Class, Length: 137, dtype: int32

# %%
for i in (0,1):
    for j in (0,1):
        myval = int((i and j) or (not (i or j)))
        print(str(i) + ' xnor ' + str(j) + ' = ' + str(myval))
# Out:
# 0 xnor 0 = 1
# 0 xnor 1 = 0
# 1 xnor 0 = 0
# 1 xnor 1 = 1

# %%
#(i and j) or (not (i or j))
def xnor(i, j):
  return int((i and j) or (not (i or j)))

# %%
testdf = pd.DataFrame()
testdf['yhat_test'] = yhat_test
testdf['y_test'] = yy_test
testdf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\users\gerri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3892, in DataFrame._ensure_valid_index(self, value)
#    3891 try:
# -> 3892     value = Series(value)
#    3893 except (ValueError, NotImplementedError, TypeError) as err:
#
# File c:\users\gerri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py:451, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     450 else:
# --> 451     data = sanitize_array(data, index, dtype, copy)
#     453     manager = get_option("mode.data_manager")
#
# File c:\users\gerri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\construction.py:601, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     599             subarr = maybe_infer_to_datetimelike(subarr)
# --> 601 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     603 if isinstance(subarr, np.ndarray):
#     604     # at this point we should have dtype be None or subarr.dtype == dtype
#
# File c:\users\gerri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\construction.py:652, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     651         return result
# --> 652     raise ValueError("Data must be 1-dimensional")
#     653 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     654     # i.e. PandasDtype("O")
#
# ValueError: Data must be 1-dimensional
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [37], line 2
#       1 testdf = pd.DataFrame()
# ----> 2 testdf['yhat_test'] = yhat_test
#       3 testdf['y_test'] = yy_test
#       4 testdf
#
# File c:\users\gerri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File c:\users\gerri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\users\gerri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4528, in DataFrame._sanitize_column(self, value)
#    4515 def _sanitize_column(self, value) -> ArrayLike:
#    4516     """
#    4517     Ensures new columns (which go into the BlockManager as new blocks) are
#    4518     always copied and converted into an array.
#    (...)
#    4526     numpy.ndarray or ExtensionArray
#    4527     """
# -> 4528     self._ensure_valid_index(value)
#    4530     # We should never get here with DataFrame value
#    4531     if isinstance(value, Series):
#
# File c:\users\gerri\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3894, in DataFrame._ensure_valid_index(self, value)
#    3892         value = Series(value)
#    3893     except (ValueError, NotImplementedError, TypeError) as err:
# -> 3894         raise ValueError(
#    3895             "Cannot set a frame with no defined index "
#    3896             "and a value that cannot be converted to a Series"
#    3897         ) from err
#    3899 # GH31368 preserve name of index
#    3900 index_copy = value.index.copy()
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
testdf['correct'] = testdf.apply(lambda x: xnor(x.yhat_test, x.y_test), axis=1)
testdf

# %%
testdf.correct.sum()

# %% [markdown]
# Now we can loop through the set of predicitons for the test set (called Y_pred) and the actual values for the test set (celled Y_test), and see how alike they are -- if they are the same, I'll increment 'correct', otherwise I'll incrememnt 'wrong'.
#
# You'll see the result is 100% accurate, even though the neural network reported a lower accuracy than that. Why?

# %%
print("Total " + str(testdf.shape[0]))
print("Correct " + str(testdf.correct.sum()))
print("Wrong " + str(testdf.shape[0] - testdf.correct.sum()))

# %%
((yhat_test - y_test)**2).sum()

# %%
y_test.shape[0] - ((yhat_test - y_test)**2).sum()

# %%
(y_test.shape[0] - ((yhat_test - y_test)**2).sum())/y_test.shape[0]
